# %%
from sklearn.linear_model import LinearRegression
from scipy.optimize import curve_fit
from matplotlib import colormaps, cm
from mpl_toolkits.axisartist.axislines import AxesZero
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # 3.6.4

# %%
# Change file directory
os.chdir(r'C:\Users\utente\OneDrive\Desktop\SCHOOL FILES\ERASMUS MUNDUS RADMEP\UJM\Laser Physics\Laboratory\Lab 2 - He-Ne Laser\labL\3.6.4')

# %%
im_30cm = np.array(Image.open("30cm.jpg"))
im_40cm = np.array(Image.open("40cm.jpg"))
im_50cm = np.array(Image.open("50cm.jpg"))
im_60cm = np.array(Image.open("60cm.jpg"))
im_70cm = np.array(Image.open("70cm.jpg"))
im_80cm = np.array(Image.open("80cm.jpg"))
im_90cm = np.array(Image.open("90cm.jpg"))
im_100cm = np.array(Image.open("100cm.jpg"))

# For data
im30cmv = im_30cm[:, 676]
im40cmv = im_40cm[:, 800]
im50cmv = im_50cm[:, 775]
im60cmv = im_60cm[:, 800]
im70cmv = im_70cm[:, 810]
im80cmv = im_80cm[:, 760]
im90cmv = im_90cm[:, 725]
im100cmv = im_100cm[:, 1025]

# For easier data processing
gaussians = [im30cmv,
        im40cmv,
        im50cmv,
        im60cmv,
        im70cmv,
        im80cmv,
        im90cmv,
        im100cmv]

pxsize = 2.8e-6 # in m
centers = [675, 575, 500, 400, 325, 225, 485, 575]


# Plot each and choose the vertical line at which the axial profile will be studied



# For plotting
im30cm_v = im_30cm[:, 676][675-225:675+225+1]
im40cm_v = im_40cm[:, 800][575-225:575+225+1]
im50cm_v = im_50cm[:, 775][500-225:500+225+1]
im60cm_v = im_60cm[:, 800][400-225:400+225+1]
im70cm_v = im_70cm[:, 810][325-225:325+225+1]
im80cm_v = im_80cm[:, 760][0:450+1]
im90cm_v = im_90cm[:, 725][275:725+1]
im100cm_v = im_100cm[:, 1025][575-225:575+225+1]

def norm(array):
    return array / array.max()


im30tr = im_30cm[675-225:675+225+1, 676-225:676+225+1]
im40tr = im_40cm[575-225:575+225+1, 800-225:800+225+1]
im50tr = im_50cm[500-225:500+225+1, 775-225:775+225+1]
im60tr = im_60cm[400-225:400+225+1, 800-225:800+225+1]
im70tr = im_70cm[325-225:325+225+1, 810-225:810+225+1]
im80tr = im_80cm[0:450+1, 760-225:760+225+1]
im90tr = im_90cm[275:725+1, 725-225:725+225+1]
im100tr = im_100cm[575-225:575+225+1, 1025-225:1025+225+1]

imagestr = [im30tr,
           im40tr,
           im50tr,
           im60tr,
           im70tr,
           im80tr,
           im90tr,
           im100tr,]

fig, axs = plt.subplots(1, 8, figsize = (14, 2), sharex = "col", sharey = "row", layout = "constrained")
# gs = fig.add_gridspec(1, 8, hspace=0, wspace=0.1)
# (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = gs.subplots(sharex = "col", sharey = "row")
# axs = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]
# # From https://www.tutorialspoint.com/how-to-draw-axis-in-the-middle-of-a-figure-in-matplotlib
# ax.spines["bottom"].set_position("center")
maxval = im30cmv.max()
def norm_(array):
    return array / maxval
# ax1_ = ax1.imshow(imagestr[0], cmap = "gray", vmax = 255)
# for i, ax in enumerate(axs):
for i in range(8):
    axs[i].imshow(imagestr[i], cmap = "gray", vmax = 255, vmin = 0, extent = [-0.6314, 0.6314, -0.6314, 0.6314])
# plt.colorbar(ax1_, ax = ax8, shrink = 0.1)
# fig.tight_layout()
fig.supxlabel("x, mm")
fig.supylabel("y, mm")
plt.savefig("transverse_images.jpg")
plt.show()

# %%
im_30cm = np.array(Image.open("30cm.jpg"))
im_40cm = np.array(Image.open("40cm.jpg"))
im_50cm = np.array(Image.open("50cm.jpg"))
im_60cm = np.array(Image.open("60cm.jpg"))
im_70cm = np.array(Image.open("70cm.jpg"))
im_80cm = np.array(Image.open("80cm.jpg"))
im_90cm = np.array(Image.open("90cm.jpg"))
im_100cm = np.array(Image.open("100cm.jpg"))

# For data
im30cmv = im_30cm[:, 676]
im40cmv = im_40cm[:, 800]
im50cmv = im_50cm[:, 775]
im60cmv = im_60cm[:, 800]
im70cmv = im_70cm[:, 810]
im80cmv = im_80cm[:, 760]
im90cmv = im_90cm[:, 725]
im100cmv = im_100cm[:, 1025]

# For easier data processing
gaussians = [im30cmv,
        im40cmv,
        im50cmv,
        im60cmv,
        im70cmv,
        im80cmv,
        im90cmv,
        im100cmv]

pxsize = 2.8e-6 # in m
centers = [675, 575, 500, 400, 325, 225, 485, 575]


# Plot each and choose the vertical line at which the axial profile will be studied



# For plotting
im30cm_v = im_30cm[:, 676][675-225:675+225+1]
im40cm_v = im_40cm[:, 800][575-225:575+225+1]
im50cm_v = im_50cm[:, 775][500-225:500+225+1]
im60cm_v = im_60cm[:, 800][400-225:400+225+1]
im70cm_v = im_70cm[:, 810][325-225:325+225+1]
im80cm_v = im_80cm[:, 760][0:450+1]
im90cm_v = im_90cm[:, 725][275:725+1]
im100cm_v = im_100cm[:, 1025][575-225:575+225+1]

def norm(array):
    return array / array.max()

# from https://www.geeksforgeeks.org/python-gaussian-fit/
def gauss(x, a, b):
        y = a * np.exp(-1*b*x**2)
        return y
def gauss_fit(array1, array2, a):
    param, cov = curve_fit(gauss, array1, array2)
    return param[0], param[1]

# For easier data processing
gaussians = [im30cmv,
        im40cmv,
        im50cmv,
        im60cmv,
        im70cmv,
        im80cmv,
        im90cmv,
        im100cmv]

# Determine length given that a pixel of the camers is 2.8 x 2.8 um
# length = 2.8*len(xx)*1e-4
# xxnew

fig = plt.figure(figsize = (8, 4))

ax = fig.add_subplot(axes_class = AxesZero)

# From https://www.tutorialspoint.com/how-to-draw-axis-in-the-middle-of-a-figure-in-matplotlib
ax.spines["bottom"].set_position("center")

for direction in ["xzero", "yzero"]:
    ax.axis[direction].set_axisline_style("-|>")
    ax.axis[direction].set_visible(False)

for direction in ["left", "bottom"]:
    ax.axis[direction].set_axisline_style("-|>")
    ax.axis[direction].set_visible(True)

for direction in ["right", "top"]:
    ax.axis[direction].set_visible(False)

# # From https://www.tutorialspoint.com/how-to-draw-axis-in-the-middle-of-a-figure-in-matplotlib
# ax.spines["bottom"].set_position("center")

lambda_ = 632.8e-9
widths = []
for i in range(len(gaussians)):
    xvals = np.linspace(- pxsize * (centers[i] + 1), (1200 - centers[i])*pxsize, 1200)
    z_ = (30 + i*10)*1e-2
    param, cov = curve_fit(gauss, xvals, gaussians[i])
    # omega_0 = (lambda_ * z_ / np.pi) * np.sqrt(param[1] / 2)
    # omega_0 = np.sqrt(4 / param[1]**2 - lambda_**2 * z_**2 / np.pi**2)
    print("- For {} cm\nA: {}\nB".format(30 + i*10, param[0], param[1]))
    # ax.plot(norm(gauss(xvals, param[0], param[1]))*8 + 30 + i*10, xvals*1e3, color = "black", linestyle = "--", linewidth = "1.5")
    # ax.scatter(norm(gaussians[i])*8 + 30 + i*10, xvals*1e3, color = "red", alpha = 0.5, s = 1.5)
    widths.append(np.sqrt(2 / param[1]))
    plt.plot(z_*1e-2, np.sqrt(2 / param[1]))
# plt.grid()


vals = [30 + i * 10 for i in range(8)]
def func(x, m):
    return m * x
l = 5
popt, cov = curve_fit(func, np.array(vals)*1e-2, np.array(widths))
# plt.plot(vals, func(np.array(vals)*1e-2, popt[0])*1e3)
omega0 = lambda_ / (popt[0] * np.pi)
print(omega0)

# omega_0_vals = np.array(omega_0_vals)
# print(omega_0_vals.mean())
# print(omega_0_vals.std())

# omega0 = omega_0_vals.mean() # in um

z0 = np.pi * omega0**2 / lambda_
def w(z):
    return omega0 * np.sqrt(1 + (z**2 / z0**2))
def R(z):
    return z + (np.pi * omega0**2 / lambda_)**2 / z
def circleup(x, r):
    return np.sqrt(r**2 - x**2)

for i in range(8):
    z = 30 + i * 10
    r = R(z * 1e-2)
    xrange = np.linspace(- w(z*1e-2) * 1e3, w(z*1e-2) * 1e3, 100)
    vals_ = circleup(xrange*1e-3, r)*1e2
    vals_ = vals_ - np.min(vals_) + z
    # xrange = np.linspace(- r * 1e3, r * 1e3, 100)
    plt.plot(vals_, xrange, color = "black", linewidth = 1.5, linestyle = "--", zorder = 50)

pts = 2000
xxvals = np.linspace(0, 101, pts)
cmap = plt.get_cmap("jet_r")
norm = plt.Normalize(5, xxvals.max())
colors = cmap(norm(xxvals))
for i in range(pts):
    l_ = w(xxvals[i]*1e-2)*1e3
    plt.vlines(xxvals[i], -l_, l_, color = colors[i], alpha = 0.2)

xvalsn = np.linspace(0, 101, 101)
plt.plot(xvalsn, w(xvalsn * 1e-2)*1e3, color = "black", linestyle = "-", linewidth = 1)
plt.plot(xvalsn, -w(xvalsn * 1e-2)*1e3, color = "black", linestyle = "-", linewidth = 1)
plt.scatter(vals, np.array(widths)*1e3, marker = "x", zorder = 100, color = "red", s = 100, label = r"$1/e^2$ of maximum of Gaussian fit")
plt.scatter(vals, np.array(widths)*1e3, marker = "o", zorder = 100, color = "red", s = 20)
# plt.arrow(0, -omega0*1e3, 0, omega0*1e3)
# plt.scatter(0, omega0*1e3)
# plt.scatter(0, -omega0*1e3)
plt.ylim(-1.3, 1.3)
plt.xlabel("z, cm")
plt.ylabel("y, mm")
plt.legend()
# plt.grid()
plt.savefig("Gausian_beam.jpg")
plt.show()

print("omega0: {} mm".format(omega0 * 1e3))
print("z0: {} cm".format(z0 * 1e2))
# Out:
# - For 30 cm
# A: 224.36243108010547
# B
# - For 40 cm
# A: 212.31044867598933
# B
# - For 50 cm
# A: 190.2223948296062
# B
# - For 60 cm
# A: 170.9955230794778
# B
# - For 70 cm
# A: 160.4371229803355
# B
# - For 80 cm
# A: 144.90482875452554
# B
# - For 90 cm
# A: 138.3882544872804
# B
# - For 100 cm
# A: 129.125269496982
# B
# 0.00017202287237060002
# omega0: 0.17202287237060002 mm
# z0: 14.691149977605535 cm

# %%
im_30cm = np.array(Image.open("30cm.jpg"))
im_40cm = np.array(Image.open("40cm.jpg"))
im_50cm = np.array(Image.open("50cm.jpg"))
im_60cm = np.array(Image.open("60cm.jpg"))
im_70cm = np.array(Image.open("70cm.jpg"))
im_80cm = np.array(Image.open("80cm.jpg"))
im_90cm = np.array(Image.open("90cm.jpg"))
im_100cm = np.array(Image.open("100cm.jpg"))

# For data
im30cmv = im_30cm[:, 676]
im40cmv = im_40cm[:, 800]
im50cmv = im_50cm[:, 775]
im60cmv = im_60cm[:, 800]
im70cmv = im_70cm[:, 810]
im80cmv = im_80cm[:, 760]
im90cmv = im_90cm[:, 725]
im100cmv = im_100cm[:, 1025]

# For easier data processing
gaussians = [im30cmv,
        im40cmv,
        im50cmv,
        im60cmv,
        im70cmv,
        im80cmv,
        im90cmv,
        im100cmv]

pxsize = 2.8e-6 # in m
centers = [675, 575, 500, 400, 325, 225, 485, 575]


# Plot each and choose the vertical line at which the axial profile will be studied



# For plotting
im30cm_v = im_30cm[:, 676][675-225:675+225+1]
im40cm_v = im_40cm[:, 800][575-225:575+225+1]
im50cm_v = im_50cm[:, 775][500-225:500+225+1]
im60cm_v = im_60cm[:, 800][400-225:400+225+1]
im70cm_v = im_70cm[:, 810][325-225:325+225+1]
im80cm_v = im_80cm[:, 760][0:450+1]
im90cm_v = im_90cm[:, 725][275:725+1]
im100cm_v = im_100cm[:, 1025][575-225:575+225+1]

def norm(array):
    return array / array.max()

# from https://www.geeksforgeeks.org/python-gaussian-fit/
def gauss(x, a, b):
        y = a * np.exp(-1*b*x**2)
        return y
def gauss_fit(array1, array2, a):
    param, cov = curve_fit(gauss, array1, array2)
    return param[0], param[1]

# For easier data processing
gaussians = [im30cmv,
        im40cmv,
        im50cmv,
        im60cmv,
        im70cmv,
        im80cmv,
        im90cmv,
        im100cmv]

# Determine length given that a pixel of the camers is 2.8 x 2.8 um
# length = 2.8*len(xx)*1e-4
# xxnew

fig = plt.figure(figsize = (8, 4))

ax = fig.add_subplot(axes_class = AxesZero)

# From https://www.tutorialspoint.com/how-to-draw-axis-in-the-middle-of-a-figure-in-matplotlib
ax.spines["bottom"].set_position("center")

for direction in ["xzero", "yzero"]:
    ax.axis[direction].set_axisline_style("-|>")
    ax.axis[direction].set_visible(False)

for direction in ["left", "bottom"]:
    ax.axis[direction].set_axisline_style("-|>")
    ax.axis[direction].set_visible(True)

for direction in ["right", "top"]:
    ax.axis[direction].set_visible(False)

# # From https://www.tutorialspoint.com/how-to-draw-axis-in-the-middle-of-a-figure-in-matplotlib
# ax.spines["bottom"].set_position("center")

lambda_ = 632.8e-9
widths = []
for i in range(len(gaussians)):
    xvals = np.linspace(- pxsize * (centers[i] + 1), (1200 - centers[i])*pxsize, 1200)
    z_ = (30 + i*10)*1e-2
    param, cov = curve_fit(gauss, xvals, gaussians[i])
    # omega_0 = (lambda_ * z_ / np.pi) * np.sqrt(param[1] / 2)
    # omega_0 = np.sqrt(4 / param[1]**2 - lambda_**2 * z_**2 / np.pi**2)
    print("- For {} cm\nA: {}\nB".format(30 + i*10, param[0], param[1]))
    # ax.plot(norm(gauss(xvals, param[0], param[1]))*8 + 30 + i*10, xvals*1e3, color = "black", linestyle = "--", linewidth = "1.5")
    # ax.scatter(norm(gaussians[i])*8 + 30 + i*10, xvals*1e3, color = "red", alpha = 0.5, s = 1.5)
    widths.append(np.sqrt(2 / param[1]))
    plt.plot(z_*1e-2, np.sqrt(2 / param[1]))
# plt.grid()


vals = [30 + i * 10 for i in range(8)]
def func(x, m):
    return m * x
l = 5
popt, cov = curve_fit(func, np.array(vals)*1e-2, np.array(widths))
# plt.plot(vals, func(np.array(vals)*1e-2, popt[0])*1e3)
omega0 = lambda_ / (popt[0] * np.pi)
print(omega0)

# omega_0_vals = np.array(omega_0_vals)
# print(omega_0_vals.mean())
# print(omega_0_vals.std())

# omega0 = omega_0_vals.mean() # in um

z0 = np.pi * omega0**2 / lambda_
def w(z):
    return omega0 * np.sqrt(1 + (z**2 / z0**2))
def R(z):
    return z + (np.pi * omega0**2 / lambda_)**2 / z
def circleup(x, r):
    return np.sqrt(r**2 - x**2)

for i in range(8):
    z = 30 + i * 10
    r = R(z * 1e-2)
    xrange = np.linspace(- w(z*1e-2) * 1e3, w(z*1e-2) * 1e3, 100)
    vals_ = circleup(xrange*1e-3, r)*1e2
    vals_ = vals_ - np.min(vals_) + z
    # xrange = np.linspace(- r * 1e3, r * 1e3, 100)
    plt.plot(vals_, xrange, color = "black", linewidth = 1.5, linestyle = "--", zorder = 50)

pts = 2000
xxvals = np.linspace(0, 101, pts)
cmap = plt.get_cmap("jet_r")
norm = plt.Normalize(5, xxvals.max())
colors = cmap(norm(xxvals))
for i in range(pts):
    l_ = w(xxvals[i]*1e-2)*1e3
    plt.vlines(xxvals[i], -l_, l_, color = colors[i], alpha = 0.2)

xvalsn = np.linspace(0, 101, 101)
plt.plot(xvalsn, w(xvalsn * 1e-2)*1e3, color = "black", linestyle = "-", linewidth = 1)
plt.plot(xvalsn, -w(xvalsn * 1e-2)*1e3, color = "black", linestyle = "-", linewidth = 1)
plt.scatter(vals, np.array(widths)*1e3, marker = "x", zorder = 100, color = "red", s = 100, label = r"$1/e^2$ of maximum of Gaussian fit")
plt.scatter(vals, np.array(widths)*1e3, marker = "o", zorder = 100, color = "red", s = 20)
# plt.arrow(0, -omega0*1e3, 0, omega0*1e3)
# plt.scatter(0, omega0*1e3)
# plt.scatter(0, -omega0*1e3)
plt.ylim(-1.3, 1.3)
plt.xlabel("z, cm")
plt.ylabel("y, mm")
plt.legend()
# plt.grid()
plt.savefig("Gausian_beam.jpg")
plt.show()

print("theta: {}".format(popt[0]))
print("omega0: {} mm".format(omega0 * 1e3))
print("z0: {} cm".format(z0 * 1e2))
# Out:
# - For 30 cm
# A: 224.36243108010547
# B
# - For 40 cm
# A: 212.31044867598933
# B
# - For 50 cm
# A: 190.2223948296062
# B
# - For 60 cm
# A: 170.9955230794778
# B
# - For 70 cm
# A: 160.4371229803355
# B
# - For 80 cm
# A: 144.90482875452554
# B
# - For 90 cm
# A: 138.3882544872804
# B
# - For 100 cm
# A: 129.125269496982
# B
# 0.00017202287237060002
# theta: 0.001170928570144769
# omega0: 0.17202287237060002 mm
# z0: 14.691149977605535 cm

# %%
im_30cm = np.array(Image.open("30cm.jpg"))
im_40cm = np.array(Image.open("40cm.jpg"))
im_50cm = np.array(Image.open("50cm.jpg"))
im_60cm = np.array(Image.open("60cm.jpg"))
im_70cm = np.array(Image.open("70cm.jpg"))
im_80cm = np.array(Image.open("80cm.jpg"))
im_90cm = np.array(Image.open("90cm.jpg"))
im_100cm = np.array(Image.open("100cm.jpg"))

# For data
im30cmv = im_30cm[:, 676]
im40cmv = im_40cm[:, 800]
im50cmv = im_50cm[:, 775]
im60cmv = im_60cm[:, 800]
im70cmv = im_70cm[:, 810]
im80cmv = im_80cm[:, 760]
im90cmv = im_90cm[:, 725]
im100cmv = im_100cm[:, 1025]

# For easier data processing
gaussians = [im30cmv,
        im40cmv,
        im50cmv,
        im60cmv,
        im70cmv,
        im80cmv,
        im90cmv,
        im100cmv]

pxsize = 2.8e-6 # in m
centers = [[675, 575, 500, 400], [325, 225, 485, 575]]

# Plot each and choose the vertical line at which the axial profile will be studied



# For plotting
im30cm_v = im_30cm[:, 676][675-225:675+225+1]
im40cm_v = im_40cm[:, 800][575-225:575+225+1]
im50cm_v = im_50cm[:, 775][500-225:500+225+1]
im60cm_v = im_60cm[:, 800][400-225:400+225+1]
im70cm_v = im_70cm[:, 810][325-225:325+225+1]
im80cm_v = im_80cm[:, 760][0:450+1]
im90cm_v = im_90cm[:, 725][275:725+1]
im100cm_v = im_100cm[:, 1025][575-225:575+225+1]

def norm(array):
    return array / array.max()

# from https://www.geeksforgeeks.org/python-gaussian-fit/
def gauss(x, a, b):
        y = a * np.exp(-1*b*x**2)
        return y
def gauss_fit(array1, array2, a):
    param, cov = curve_fit(gauss, array1, array2)
    return param[0], param[1]

# For easier data processing
gaussians = [[im30cmv,
        im40cmv,
        im50cmv,
        im60cmv],
        [im70cmv,
        im80cmv,
        im90cmv,
        im100cmv]]

z_vals = [[30, 40, 50, 60], [70, 80, 90, 100]]


# Determine length given that a pixel of the camers is 2.8 x 2.8 um
# length = 2.8*len(xx)*1e-4
# xxnew

# From https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html
fig, ax = plt.subplots(2, 4, figsize = (15, 5), sharex = "col", sharey = "row", layout = "constrained")
# gs = fig.add_gridspec(2, 4, hspace=0.1, wspace=0.1)
# (ax1, ax2, ax3, ax4), (ax5, ax6, ax7, ax8) = gs.subplots(sharex = "col", sharey = "row")
# axs = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]
# # From https://www.tutorialspoint.com/how-to-draw-axis-in-the-middle-of-a-figure-in-matplotlib
# ax.spines["bottom"].set_position("center")
maxval = im30cmv.max()
def norm_(array):
    return array / maxval

lambda_ = 632.8e-9
omega_0_vals = []
widths = []
maxval_ = 1
# for i, ax in enumerate(axs):
for i in range(2):
    for j in range(4):
        xvals = np.linspace(- pxsize * (centers[i][j] + 1), (1200 - centers[i][j])*pxsize, 1200)
        z_ = z_vals[i][j]
        param, cov = curve_fit(gauss, xvals, gaussians[i][j])
        # omega_0 = (lambda_ * z_ / np.pi) * np.sqrt(param[1] / 2)
        # omega_0 = np.sqrt(4 / param[1]**2 - lambda_**2 * z_**2 / np.pi**2)
        # print("- For {} cm\nA: {}\nB: {}\nomega: {}".format(30 + i*10, param[0], param[1], omega_0))
        if i == 0 and j == 0:
            maxval_ = np.max(gauss(xvals, param[0], param[1]))
        # else:
        #     maxval_ = 1
        ax[i,j].plot(xvals*1e3, gauss(xvals, param[0], param[1]) / maxval_, color = "black", linestyle = "--", linewidth = "1.5")
        ax[i,j].scatter(xvals*1e3, norm_(gaussians[i][j]), color = "red", alpha = 0.5, s = 1.5)
        ax[i,j].text(-2.6, 0.81, "z = {} cm".format(z_), fontsize = 11, color = "red", bbox = dict(facecolor = "white", edgecolor = "red", alpha = 0.7))
        ax[i,j].set_ylim(0, 1)
        ax[i,j].set_xlim(-2.8, 2.8)
        # ax.set_xlabel("x, mm")
        ax[i,j].grid()
    # ax.legend()
    # widths.append(np.sqrt(2 / param[1]))
# plt.grid()
fig.supxlabel("y, mm")
# fig.tight_layout()
fig.supylabel("Intensity")
plt.savefig("intensities.jpg")
plt.show()

# %% [markdown]
# # Power

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# distances in cm
dist = np.array([0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65]) + 28.5
# in uW
power = np.array([1430, 1.3e3, 720, 450, 260, 540, 220, 500, 680, 750, 2.15e3, 610, 140, 30])

plt.plot(dist[:5], power[:5], marker = "o")
plt.plot(dist[5:], power[5:], marker = "o")
plt.xlabel("Distance, cm")
plt.ylabel(r"Power, $\mu$W")
plt.grid()
plt.savefig("power.jpg")
plt.show()
